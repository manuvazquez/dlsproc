# %%
import pathlib
import itertools

import pandas as pd
from IPython.display import display
import yaml

import dlsproc.bundle
import dlsproc.hier
import dlsproc.postprocess
import dlsproc.assemble

# %% [markdown]
# So that *all* the columns of a `pd.DataFrame` are shown:

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Parameters

# %% [markdown]
# The directory containing downloaded data:

# %%
data_directory = pathlib.Path.cwd().parent / 'data'
assert data_directory.exists()
print(data_directory)
# Out:
# /home/manu/dlsproc/data

# %% [markdown]
# Directory in which the data is to be saved

# %%
output_directory = pathlib.Path.cwd()
assert output_directory.exists()
print(output_directory)
# Out:
# /home/manu/dlsproc/reports

# %% [markdown]
# The name of the file **without** extension

# %%
output_file = output_directory / '2018-2021'
print(f'{output_file} (existing? {output_file.exists()})')
# Out:
# /home/manu/dlsproc/reports/2018-2021 (existing? False)

# %% [markdown]
# # Processing

# %% [markdown]
# > Licitaciones publicadas en la Plataforma mediante mecanismos de agregación, excluyendo los contratos menores

# %% [markdown]
# The directory for *outsiders* data

# %%
# outsiders_directory = data_directory / 'agregados'
outsiders_directory = pathlib.Path.cwd().parent / 'samples' / 'yearly'
assert outsiders_directory.exists()
print(outsiders_directory)
# Out:
# /home/manu/dlsproc/samples/yearly

# %% [markdown]
# The list of files to be processed. They were downloaded [here](https://www.hacienda.gob.es/es-ES/GobiernoAbierto/Datos%20Abiertos/Paginas/LicitacionesAgregacion.aspx). One could use something like
# ```
# wget https://contrataciondelsectorpublico.gob.es/sindicacion/sindicacion_1044/PlataformasAgregadasSinMenores_2018.zip
# ```

# %%
zip_files = [
    'PlataformasAgregadasSinMenores_2018.zip',
    'PlataformasAgregadasSinMenores_2019.zip',
    'PlataformasAgregadasSinMenores_2020.zip',
    'PlataformasAgregadasSinMenores_2021.zip'
]

# %% [markdown]
# Accumulators for the data itself (contracts) and records of deleted entries

# %%
res_df = None
res_deleted_series = None

# %% [markdown]
# Every file is processed in a loop

# %%
# %%time
for filename in zip_files:
    
    print(f'Processing "{filename}"')
    
    # above file names are relative to a directory
    f = outsiders_directory / filename
    
    assert f.exists()
    
    # data is read from the above *zip* file, and concatenated into a single `pd.DataFrame`...
    yearly_df = dlsproc.bundle.read_zip(f, concatenate=True)
    
    # ...and re-structured with multiindexed columns
    yearly_df = dlsproc.hier.flat_df_to_multiindexed_df(yearly_df)
    
    # the same contract might show up more than once due to updates...but only the last one is kept
    last_update_only_df = dlsproc.postprocess.keep_updates_only(yearly_df)
    
    # the same zip file also contains information (at the beginning) about deleted entries
    deleted_series = dlsproc.bundle.read_deleted_zip(f)
    
    # if this is NOT the first iteration...
    if res_df is not None:
    
        # ...the new data is stacked
        res_df = dlsproc.assemble.stack(res_df, last_update_only_df)
        res_deleted_series = pd.concat((res_deleted_series, deleted_series), axis=0)
        
    # ...if this is the first iteration
    else:
        
        # ...the new data is set as the accumulated result
        res_df = last_update_only_df
        res_deleted_series = deleted_series
# Out:
# Processing "PlataformasAgregadasSinMenores_2018.zip"
# Processing "PlataformasAgregadasSinMenores_2019.zip"
# Processing "PlataformasAgregadasSinMenores_2020.zip"
# Processing "PlataformasAgregadasSinMenores_2021.zip"
# CPU times: user 7.6 s, sys: 36.8 ms, total: 7.63 s
# Wall time: 7.63 s

# %%
res_df.head(2)
# Out:
#                                                                                                          id  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    https://contrataciondelestado.es/sindicacion/P...
#                                                    452    https://contrataciondelestado.es/sindicacion/P...
#
#                                                                                                     summary  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Expediente: 1284/17, Entidad: Diputación Provi...
#                                                    452    Expediente: 1282/17, Entidad: Diputación Provi...
#
#                                                                                                       title  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#
#                                                                                   updated  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453   2018-01-02 08:01:52.024000+00:00
#                                                    452   2018-01-02 08:02:24.833000+00:00
#
#                                                          ContractFolderStatus  \
#                                                              ContractFolderID
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1284/17
#                                                    452                1282/17
#
#                                                                                    \
#                                                          ContractFolderStatusCode
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                        RES
#                                                    452                        RES
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                                            Party
#                                                              PartyIdentification
#                                                                               ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 L02000047
#                                                    452                 L02000047
#
#                                                                                                \
#
#
#                                                                                     PartyName
#                                                                                          Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Diputación Provincial de Valladolid
#                                                    452    Diputación Provincial de Valladolid
#
#                                                                                                              \
#                                                                                          ProcurementProject
#                                                                                                        Name
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#
#                                                                    \
#
#                                                          TypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        3.0
#                                                    452        3.0
#
#                                                                                          \
#
#                                                                            BudgetAmount
#                                                          EstimatedOverallContractAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         89917.95
#                                                    452                        175708.46
#
#                                                                              \
#
#
#                                                          TaxExclusiveAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453             89917.95
#                                                    452            175708.46
#
#                                                                                           \
#
#                                                          RequiredCommodityClassification
#                                                                   ItemClassificationCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                          45233142
#                                                    452                          45233142
#
#                                                                                \
#
#                                                              RealizedLocation
#                                                          CountrySubentityCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  ES418
#                                                    452                  ES418
#
#                                                                         \
#
#                                                          PlannedPeriod
#                                                              StartDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453            <NA>
#                                                    452            <NA>
#
#                                                                                \
#                                                                  TenderResult
#                                                                    ResultCode
#                                                          EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453      <NA>            8
#                                                    452      <NA>            8
#
#                                                                                  \
#
#                                                          ReceivedTenderQuantity
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                       14
#                                                    452                       13
#
#                                                                               \
#
#                                                                 WinningParty
#                                                          PartyIdentification
#                                                                           ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453             A47082185
#                                                    452             A49012792
#
#                                                                                                \
#
#
#                                                                                     PartyName
#                                                                                          Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    CONSTRUCCIONES HERMANOS SASTRE S.A.
#                                                    452    CONTRATAS Y OBRAS SAN GREGORIO S.A.
#
#                                                                                  \
#
#                                                          AwardedTenderedProject
#                                                              LegalMonetaryTotal
#                                                              TaxExclusiveAmount
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 60690.08
#                                                    452                118919.49
#
#                                                                            \
#                                                          TenderingProcess
#                                                             ProcedureCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1.0
#                                                    452                1.0
#
#                                                                                          \
#
#                                                          TenderSubmissionDeadlinePeriod
#                                                                                 EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                       2017-11-02
#                                                    452                       2017-11-02
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#
#                                                                           \
#                                                          ValidNoticeInfo
#                                                           NoticeTypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453          DOC_FORM
#                                                    452          DOC_FORM
#
#                                                                                                              \
#
#                                                                                 AdditionalPublicationStatus
#                                                                                        PublicationMediaName
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Publicación del anuncio de formalización en un...
#                                                    452    Publicación del anuncio de formalización en un...
#
#                                                                                                  \
#
#
#                                                          AdditionalPublicationDocumentReference
#                                                                                       IssueDate
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                               2018-01-02
#                                                    452                               2018-01-02
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                               ParentLocatedParty
#                                                                        PartyName
#                                                                             Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      <NA>
#                                                    452                      <NA>
#
#                                                                              \
#
#
#                                                          ParentLocatedParty
#                                                                   PartyName
#                                                                        Name
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 <NA>
#                                                    452                 <NA>
#
#                                                                              \
#                                                          ProcurementProject
#                                                               PlannedPeriod
#                                                             DurationMeasure
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  3.0
#                                                    452                  3.0
#
#                                                                                   \
#                                                                     TenderResult
#                                                           AwardedTenderedProject
#                                                          ProcurementProjectLotID
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         1
#                                                    452                         1
#
#                                                                                  \
#                                                          LegalDocumentReference
#                                                                              ID
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                     <NA>
#                                                    452                     <NA>
#
#                                                                             \
#
#                                                                 Attachment
#                                                          ExternalReference
#                                                                        URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                <NA>
#                                                    452                <NA>
#
#                                                                                      \
#                                                          TechnicalDocumentReference
#                                                                                  ID
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         <NA>
#                                                    452                         <NA>
#
#                                                                             \
#
#                                                                 Attachment
#                                                          ExternalReference
#                                                                        URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                <NA>
#                                                    452                <NA>
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                                        PartyName
#                                                                             Name
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      <NA>
#                                                    452                      <NA>
#
#                                                                              \
#
#
#
#
#                                                          ParentLocatedParty
#                                                                   PartyName
#                                                                        Name
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 <NA>
#                                                    452                 <NA>
#
#                                                                                               \
#                                                                             TenderingProcess
#                                                          ParticipationRequestReceptionPeriod
#                                                                                      EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                            2017-11-02
#                                                    452                            2017-11-02
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#
#
#
#                                                          TenderSubmissionDeadlinePeriod
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        2017-11-02 23:59:00+00:00
#                                                    452        2017-11-02 23:59:00+00:00

# %% [markdown]
# How many ros and columns?

# %%
res_df.shape
# Out:
# (5062, 40)

# %% [markdown]
# The *deleted series* might contain duplicates. We build a new `pd.Series` dropping duplicates by keeping only the last one.

# %%
deduplicated_deleted_series = res_deleted_series.sort_values().groupby(res_deleted_series.index).tail(1)
deduplicated_deleted_series
# Out:
# file name                                              id
# PlataformasAgregadasSinMenores_20180217_180137_1.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1974509   2017-12-31 13:10:39.114000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1970608   2017-12-31 13:10:39.180000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1973692   2017-12-31 14:10:39.150000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1975721   2017-12-31 14:10:39.242000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1974172   2017-12-31 14:10:39.368000+01:00
#                                                                                                                                                            ...
# PlataformasAgregadasSinMenores_20210106_030028.atom    https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1954624   2021-01-05 00:11:09.664000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1954627   2021-01-05 00:11:09.718000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1954625   2021-01-05 00:11:09.776000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/4329742   2021-01-05 01:11:07.037000+01:00
#                                                        https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/5961865   2021-01-05 08:11:09.034000+01:00
# Name: deleted_on, Length: 810, dtype: datetime64[ns, pytz.FixedOffset(60)]

# %%
stateful_df = dlsproc.assemble.merge_deleted(res_df, deduplicated_deleted_series)
stateful_df
# Out:
#                                                                                                          id  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    https://contrataciondelestado.es/sindicacion/P...
#                                                    452    https://contrataciondelestado.es/sindicacion/P...
#                                                    451    https://contrataciondelestado.es/sindicacion/P...
#                                                    450    https://contrataciondelestado.es/sindicacion/P...
#                                                    449    https://contrataciondelestado.es/sindicacion/P...
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      https://contrataciondelestado.es/sindicacion/P...
#                                                    3      https://contrataciondelestado.es/sindicacion/P...
#                                                    2      https://contrataciondelestado.es/sindicacion/P...
#                                                    1      https://contrataciondelestado.es/sindicacion/P...
#                                                    0      https://contrataciondelestado.es/sindicacion/P...
#
#                                                                                                     summary  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Expediente: 1284/17, Entidad: Diputación Provi...
#                                                    452    Expediente: 1282/17, Entidad: Diputación Provi...
#                                                    451    Expediente: 1281/17, Entidad: Diputación Provi...
#                                                    450    Id licitación: VI/17/04-015; Órgano de Contrat...
#                                                    449    Id Licitación: PcPG/2017/194222, Órgano de Con...
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      Id licitación: 901800/2020; Órgano de Contrata...
#                                                    3      Id licitación: 2020ZEBO0071;  Órgano de Contra...
#                                                    2      Id licitación: 255K;  Órgano de Contratación: ...
#                                                    1      Id licitación: SA-12-2020;  Órgano de Contrata...
#                                                    0      Id licitación: SA-11-2020;  Órgano de Contrata...
#
#                                                                                                       title  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#                                                    451    Refuerzo de firme en la VP 4013 Melgar de Arri...
#                                                    450    Obras de edificación en el barrio de Pumarabul...
#                                                    449    Suministro de gas natural canalizado y gas nat...
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      Subministrament i instal.lació de les noves vi...
#                                                    3      Servicios: conservación básica, reten, reparac...
#                                                    2      CONTRATO DE EJECUCIÓN DE OBRAS DE EDIFICACIÓN ...
#                                                    1      Servicio de un sistema de grabación, creación ...
#                                                    0      Redacción, diseño gráfico, impresión de la rev...
#
#                                                                                   updated  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453   2018-01-02 08:01:52.024000+00:00
#                                                    452   2018-01-02 08:02:24.833000+00:00
#                                                    451   2018-01-02 08:02:51.744000+00:00
#                                                    450   2018-01-02 08:02:56.115000+00:00
#                                                    449   2018-01-02 09:10:49.572000+00:00
# ..                                                                                    ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4     2021-01-05 08:42:01.478000+00:00
#                                                    3     2021-01-05 08:55:41.039000+00:00
#                                                    2     2021-01-05 08:55:41.290000+00:00
#                                                    1     2021-01-05 08:55:41.492000+00:00
#                                                    0     2021-01-05 08:55:41.717000+00:00
#
#                                                          ContractFolderStatus  \
#                                                              ContractFolderID
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1284/17
#                                                    452                1282/17
#                                                    451                1281/17
#                                                    450           VI/17/04-015
#                                                    449       PcPG/2017/194222
# ..                                                                        ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4              901800/2020
#                                                    3             2020ZEBO0071
#                                                    2                     255K
#                                                    1               SA-12-2020
#                                                    0               SA-11-2020
#
#                                                                                    \
#                                                          ContractFolderStatusCode
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                        RES
#                                                    452                        RES
#                                                    451                        RES
#                                                    450                         EV
#                                                    449                        ADJ
# ..                                                                            ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                          PUB
#                                                    3                           EV
#                                                    2                           EV
#                                                    1                           EV
#                                                    0                           EV
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                                            Party
#                                                              PartyIdentification
#                                                                               ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 L02000047
#                                                    452                 L02000047
#                                                    451                 L02000047
#                                                    450                      <NA>
#                                                    449                 A12017369
# ..                                                                           ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                        <NA>
#                                                    3                        <NA>
#                                                    2                        <NA>
#                                                    1                        <NA>
#                                                    0                        <NA>
#
#                                                                                                         \
#
#
#                                                                                              PartyName
#                                                                                                   Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453             Diputación Provincial de Valladolid
#                                                    452             Diputación Provincial de Valladolid
#                                                    451             Diputación Provincial de Valladolid
#                                                    450     Consejería de Servicios y Derechos Sociales
#                                                    449    Consellería de Economía, Emprego e Industria
# ..                                                                                                 ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                   Àrea Metropolitana de Barcelona
#                                                    3                                             Pleno
#                                                    2                          Consejo de Admnistración
#                                                    1                           Junta de Gobierno Local
#                                                    0                           Junta de Gobierno Local
#
#                                                                                                              \
#                                                                                          ProcurementProject
#                                                                                                        Name
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#                                                    451    Refuerzo de firme en la VP 4013 Melgar de Arri...
#                                                    450    Edificación de 36 VPP, garaje y trasteros en e...
#                                                    449    Suministro de gas natural canalizado y gas nat...
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      Subministrament i instal.lació de les noves vi...
#                                                    3      Servicios: conservación básica, reten, reparac...
#                                                    2      Ejecución de las obras de edificación de 39 VP...
#                                                    1      Contratación del servicio de un sistema de gra...
#                                                    0      Redacción, diseño gráfico, impresión de la rev...
#
#                                                                    \
#
#                                                          TypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        3.0
#                                                    452        3.0
#                                                    451        3.0
#                                                    450        3.0
#                                                    449        1.0
# ..                                                            ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4          1.0
#                                                    3          2.0
#                                                    2          3.0
#                                                    1          2.0
#                                                    0          2.0
#
#                                                                                          \
#
#                                                                            BudgetAmount
#                                                          EstimatedOverallContractAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         89917.95
#                                                    452                        175708.46
#                                                    451                        229259.52
#                                                    450                       2850705.78
#                                                    449                              NaN
# ..                                                                                  ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                          284082.33
#                                                    3                          690803.20
#                                                    2                         6843971.79
#                                                    1                           30100.00
#                                                    0                           70000.00
#
#                                                                              \
#
#
#                                                          TaxExclusiveAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453             89917.95
#                                                    452            175708.46
#                                                    451            229259.52
#                                                    450           2850705.78
#                                                    449          29359984.62
# ..                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4              284082.33
#                                                    3              690803.20
#                                                    2             5703309.82
#                                                    1               15050.00
#                                                    0               70000.00
#
#                                                                                           \
#
#                                                          RequiredCommodityClassification
#                                                                   ItemClassificationCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                          45233142
#                                                    452                          45233142
#                                                    451                          45233142
#                                                    450                          45211340
#                                                    449                           9123000
# ..                                                                                   ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                            39171000
#                                                    3      [50711000, 50232110, 50232100]
#                                                    2                            45000000
#                                                    1                            72510000
#                                                    0                [79341000, 64111000]
#
#                                                                                \
#
#                                                              RealizedLocation
#                                                          CountrySubentityCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  ES418
#                                                    452                  ES418
#                                                    451                  ES418
#                                                    450                  ES120
#                                                    449                   ES11
# ..                                                                        ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                    ES511
#                                                    3                    ES212
#                                                    2                    ES212
#                                                    1                    ES213
#                                                    0                    ES213
#
#                                                                         \
#
#                                                          PlannedPeriod
#                                                              StartDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453            <NA>
#                                                    452            <NA>
#                                                    451            <NA>
#                                                    450            <NA>
#                                                    449            <NA>
# ..                                                                 ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4              <NA>
#                                                    3              <NA>
#                                                    2              <NA>
#                                                    1              <NA>
#                                                    0              <NA>
#
#                                                                                \
#                                                                  TenderResult
#                                                                    ResultCode
#                                                          EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453      <NA>            8
#                                                    452      <NA>            8
#                                                    451      <NA>            8
#                                                    450      <NA>          NaN
#                                                    449      <NA>       [8, 8]
# ..                                                           ...          ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4        <NA>          NaN
#                                                    3        <NA>          NaN
#                                                    2        <NA>          NaN
#                                                    1        <NA>          NaN
#                                                    0        <NA>          NaN
#
#                                                                                  \
#
#                                                          ReceivedTenderQuantity
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                       14
#                                                    452                       13
#                                                    451                       11
#                                                    450                      NaN
#                                                    449                   [3, 1]
# ..                                                                          ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                        NaN
#                                                    3                        NaN
#                                                    2                        NaN
#                                                    1                        NaN
#                                                    0                        NaN
#
#                                                                                   \
#
#                                                                     WinningParty
#                                                              PartyIdentification
#                                                                               ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 A47082185
#                                                    452                 A49012792
#                                                    451                 B49160567
#                                                    450                       NaN
#                                                    449    [A61797536, A61797536]
# ..                                                                           ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                         NaN
#                                                    3                         NaN
#                                                    2                         NaN
#                                                    1                         NaN
#                                                    0                         NaN
#
#                                                                                                              \
#
#
#                                                                                                   PartyName
#                                                                                                        Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  CONSTRUCCIONES HERMANOS SASTRE S.A.
#                                                    452                  CONTRATAS Y OBRAS SAN GREGORIO S.A.
#                                                    451                                         EXFAMEX S.L.
#                                                    450                                                  NaN
#                                                    449    [GAS NATURAL COMERCIALIZADORA, SA, GAS NATURAL...
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                                                    NaN
#                                                    3                                                    NaN
#                                                    2                                                    NaN
#                                                    1                                                    NaN
#                                                    0                                                    NaN
#
#                                                                                      \
#
#                                                              AwardedTenderedProject
#                                                                  LegalMonetaryTotal
#                                                                  TaxExclusiveAmount
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                     60690.08
#                                                    452                    118919.49
#                                                    451                    178478.55
#                                                    450                          NaN
#                                                    449    [27716723.57, 1643261.06]
# ..                                                                              ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                            NaN
#                                                    3                            NaN
#                                                    2                            NaN
#                                                    1                            NaN
#                                                    0                            NaN
#
#                                                                            \
#                                                          TenderingProcess
#                                                             ProcedureCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1.0
#                                                    452                1.0
#                                                    451                1.0
#                                                    450                1.0
#                                                    449                4.0
# ..                                                                    ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                  1.0
#                                                    3                  1.0
#                                                    2                  1.0
#                                                    1                  1.0
#                                                    0                  1.0
#
#                                                                                          \
#
#                                                          TenderSubmissionDeadlinePeriod
#                                                                                 EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                       2017-11-02
#                                                    452                       2017-11-02
#                                                    451                       2017-11-02
#                                                    450                       2017-12-11
#                                                    449                       2017-09-29
# ..                                                                                  ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                         2021-01-18
#                                                    3                         2021-01-04
#                                                    2                         2021-01-04
#                                                    1                         2021-01-04
#                                                    0                         2021-01-04
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#                                                    451    23:59:00
#                                                    450    14:00:00
#                                                    449    23:59:00
# ..                                                             ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      11:00:00
#                                                    3      23:55:00
#                                                    2      23:59:00
#                                                    1      23:59:00
#                                                    0      23:59:00
#
#                                                                                  \
#                                                                 ValidNoticeInfo
#                                                                  NoticeTypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 DOC_FORM
#                                                    452                 DOC_FORM
#                                                    451                 DOC_FORM
#                                                    450                   DOC_CN
#                                                    449    [DOC_CN, DOC_CAN_ADJ]
# ..                                                                          ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                     DOC_CN
#                                                    3                     DOC_CN
#                                                    2                     DOC_CN
#                                                    1                     DOC_CN
#                                                    0                     DOC_CN
#
#                                                                                                              \
#
#                                                                                 AdditionalPublicationStatus
#                                                                                        PublicationMediaName
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Publicación del anuncio de formalización en un...
#                                                    452    Publicación del anuncio de formalización en un...
#                                                    451    Publicación del anuncio de formalización en un...
#                                                    450    [Plataforma de Contratación del Sector Público...
#                                                    449             [BOE, DOUE, DOG, Perfil del contratante]
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                                                   DOUE
#                                                    3                                 Perfil del contratante
#                                                    2                                 Perfil del contratante
#                                                    1                                 Perfil del contratante
#                                                    0                                 Perfil del contratante
#
#                                                                                                             \
#
#
#                                                                     AdditionalPublicationDocumentReference
#                                                                                                  IssueDate
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                                          2018-01-02
#                                                    452                                          2018-01-02
#                                                    451                                          2018-01-02
#                                                    450                [2017-11-15, 2017-11-15, 2017-11-15]
#                                                    449    [2017-09-09, 2017-08-31, 2017-09-07, 2018-01-02]
# ..                                                                                                     ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                                            2020-12-23
#                                                    3                                            2020-11-30
#                                                    2                                            2020-12-03
#                                                    1                                            2020-12-17
#                                                    0                                            2020-12-17
#
#                                                                                             \
#                                                                    LocatedContractingParty
#                                                                         ParentLocatedParty
#                                                                                  PartyName
#                                                                                       Name
#
# ...
#                                                                                                         URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                                                 <NA>
#                                                    452                                                 <NA>
#                                                    451                                                 <NA>
#                                                    450    http://www.asturias.es/Proveedores/FICHEROS/ES...
#                                                    449                                                 <NA>
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      https://contractaciopublica.gencat.cat/ecofin_...
#                                                    3      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    2      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    1      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    0      https://contratacion.euskadi.eus/w32-kpeperfi/...
#
#                                                                                                           \
#                                                                               TechnicalDocumentReference
#                                                                                                       ID
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                                              <NA>
#                                                    452                                              <NA>
#                                                    451                                              <NA>
#                                                    450                                              <NA>
#                                                    449                                              <NA>
# ..                                                                                                   ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                        Memòria tècnica valorada.pdf
#                                                    3                                  Pliego técnico.pdf
#                                                    2                      255K Proyecto de ejecución.odt
#                                                    1      PLIEGO CLÁUSULAS TÉCNICAS GRABACIÓN PLENOS.doc
#                                                    0                                   PPT REVISTA-1.doc
#
#                                                                                                              \
#
#                                                                                                  Attachment
#                                                                                           ExternalReference
#                                                                                                         URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                                                 <NA>
#                                                    452                                                 <NA>
#                                                    451                                                 <NA>
#                                                    450                                                 <NA>
#                                                    449                                                 <NA>
# ..                                                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4      https://contractaciopublica.gencat.cat/ecofin_...
#                                                    3      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    2      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    1      https://contratacion.euskadi.eus/w32-kpeperfi/...
#                                                    0      https://contratacion.euskadi.eus/w32-kpeperfi/...
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                                        PartyName
#                                                                             Name
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      <NA>
#                                                    452                      <NA>
#                                                    451                      <NA>
#                                                    450                      <NA>
#                                                    449                      <NA>
# ..                                                                           ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                        <NA>
#                                                    3                        <NA>
#                                                    2                        <NA>
#                                                    1                        <NA>
#                                                    0                        <NA>
#
#                                                                              \
#
#
#
#
#                                                          ParentLocatedParty
#                                                                   PartyName
#                                                                        Name
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 <NA>
#                                                    452                 <NA>
#                                                    451                 <NA>
#                                                    450                 <NA>
#                                                    449                 <NA>
# ..                                                                      ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                   <NA>
#                                                    3                   <NA>
#                                                    2                   <NA>
#                                                    1                   <NA>
#                                                    0                   <NA>
#
#                                                                                               \
#                                                                             TenderingProcess
#                                                          ParticipationRequestReceptionPeriod
#                                                                                      EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                            2017-11-02
#                                                    452                            2017-11-02
#                                                    451                            2017-11-02
#                                                    450                                  <NA>
#                                                    449                                  <NA>
# ..                                                                                       ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4                                    <NA>
#                                                    3                                    <NA>
#                                                    2                                    <NA>
#                                                    1                                    <NA>
#                                                    0                                    <NA>
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#                                                    451    23:59:00
#                                                    450        <NA>
#                                                    449        <NA>
# ..                                                             ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4          <NA>
#                                                    3          <NA>
#                                                    2          <NA>
#                                                    1          <NA>
#                                                    0          <NA>
#
#                                                                                          \
#
#                                                          TenderSubmissionDeadlinePeriod
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        2017-11-02 23:59:00+00:00
#                                                    452        2017-11-02 23:59:00+00:00
#                                                    451        2017-11-02 23:59:00+00:00
#                                                    450        2017-12-11 14:00:00+00:00
#                                                    449        2017-09-29 23:59:00+00:00
# ..                                                                                  ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4          2021-01-18 11:00:00+00:00
#                                                    3          2021-01-04 23:55:00+00:00
#                                                    2          2021-01-04 23:59:00+00:00
#                                                    1          2021-01-04 23:59:00+00:00
#                                                    0          2021-01-04 23:59:00+00:00
#
#                                                          deleted_on
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453          NaT
#                                                    452          NaT
#                                                    451          NaT
#                                                    450          NaT
#                                                    449          NaT
# ..                                                              ...
# PlataformasAgregadasSinMenores_20210106_030028.... 4            NaT
#                                                    3            NaT
#                                                    2            NaT
#                                                    1            NaT
#                                                    0            NaT
#
# [5062 rows x 41 columns]

# %% [markdown]
# Saving to *pickle*

# %%
stateful_df.to_pickle(output_file.with_suffix('.pickle'))

# %% [markdown]
# Saving to *parquet*

# %%
parquet_df = dlsproc.assemble.parquet_amenable(stateful_df)
parquet_df.head(2)
# Out:
#                                                                                                          id  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    https://contrataciondelestado.es/sindicacion/P...
#                                                    452    https://contrataciondelestado.es/sindicacion/P...
#
#                                                                                                     summary  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Expediente: 1284/17, Entidad: Diputación Provi...
#                                                    452    Expediente: 1282/17, Entidad: Diputación Provi...
#
#                                                                                                       title  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#
#                                                                                   updated  \
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453   2018-01-02 08:01:52.024000+00:00
#                                                    452   2018-01-02 08:02:24.833000+00:00
#
#                                                          ContractFolderStatus  \
#                                                              ContractFolderID
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1284/17
#                                                    452                1282/17
#
#                                                                                    \
#                                                          ContractFolderStatusCode
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                        RES
#                                                    452                        RES
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                                            Party
#                                                              PartyIdentification
#                                                                               ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 L02000047
#                                                    452                 L02000047
#
#                                                                                                \
#
#
#                                                                                     PartyName
#                                                                                          Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Diputación Provincial de Valladolid
#                                                    452    Diputación Provincial de Valladolid
#
#                                                                                                              \
#                                                                                          ProcurementProject
#                                                                                                        Name
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    Refuerzo de Firme en la VP 3001 Renedo de Esgu...
#                                                    452    Refuerzo de Firme en la VP 6603 Mota del Marqu...
#
#                                                                    \
#
#                                                          TypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        3.0
#                                                    452        3.0
#
#                                                                                          \
#
#                                                                            BudgetAmount
#                                                          EstimatedOverallContractAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         89917.95
#                                                    452                        175708.46
#
#                                                                              \
#
#
#                                                          TaxExclusiveAmount
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453             89917.95
#                                                    452            175708.46
#
#                                                                                           \
#
#                                                          RequiredCommodityClassification
#                                                                   ItemClassificationCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      [45233142.0]
#                                                    452                      [45233142.0]
#
#                                                                                \
#
#                                                              RealizedLocation
#                                                          CountrySubentityCode
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  ES418
#                                                    452                  ES418
#
#                                                                         \
#
#                                                          PlannedPeriod
#                                                              StartDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453            <NA>
#                                                    452            <NA>
#
#                                                                                \
#                                                                  TenderResult
#                                                                    ResultCode
#                                                          EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453      <NA>        [8.0]
#                                                    452      <NA>        [8.0]
#
#                                                                                  \
#
#                                                          ReceivedTenderQuantity
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                   [14.0]
#                                                    452                   [13.0]
#
#                                                                               \
#
#                                                                 WinningParty
#                                                          PartyIdentification
#                                                                           ID
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453           [A47082185]
#                                                    452           [A49012792]
#
#                                                                                                  \
#
#
#                                                                                       PartyName
#                                                                                            Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    [CONSTRUCCIONES HERMANOS SASTRE S.A.]
#                                                    452    [CONTRATAS Y OBRAS SAN GREGORIO S.A.]
#
#                                                                                  \
#
#                                                          AwardedTenderedProject
#                                                              LegalMonetaryTotal
#                                                              TaxExclusiveAmount
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453               [60690.08]
#                                                    452              [118919.49]
#
#                                                                            \
#                                                          TenderingProcess
#                                                             ProcedureCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                1.0
#                                                    452                1.0
#
#                                                                                          \
#
#                                                          TenderSubmissionDeadlinePeriod
#                                                                                 EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                       2017-11-02
#                                                    452                       2017-11-02
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#
#                                                                           \
#                                                          ValidNoticeInfo
#                                                           NoticeTypeCode
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        [DOC_FORM]
#                                                    452        [DOC_FORM]
#
#                                                                                                              \
#
#                                                                                 AdditionalPublicationStatus
#                                                                                        PublicationMediaName
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    [Publicación del anuncio de formalización en u...
#                                                    452    [Publicación del anuncio de formalización en u...
#
#                                                                                                  \
#
#
#                                                          AdditionalPublicationDocumentReference
#                                                                                       IssueDate
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                             [2018-01-02]
#                                                    452                             [2018-01-02]
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                               ParentLocatedParty
#                                                                        PartyName
#                                                                             Name
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      <NA>
#                                                    452                      <NA>
#
#                                                                              \
#
#
#                                                          ParentLocatedParty
#                                                                   PartyName
#                                                                        Name
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 <NA>
#                                                    452                 <NA>
#
#                                                                              \
#                                                          ProcurementProject
#                                                               PlannedPeriod
#                                                             DurationMeasure
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                  3.0
#                                                    452                  3.0
#
#                                                                                   \
#                                                                     TenderResult
#                                                           AwardedTenderedProject
#                                                          ProcurementProjectLotID
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                     [1.0]
#                                                    452                     [1.0]
#
#                                                                                  \
#                                                          LegalDocumentReference
#                                                                              ID
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                     <NA>
#                                                    452                     <NA>
#
#                                                                             \
#
#                                                                 Attachment
#                                                          ExternalReference
#                                                                        URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                <NA>
#                                                    452                <NA>
#
#                                                                                      \
#                                                          TechnicalDocumentReference
#                                                                                  ID
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                         <NA>
#                                                    452                         <NA>
#
#                                                                             \
#
#                                                                 Attachment
#                                                          ExternalReference
#                                                                        URI
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                <NA>
#                                                    452                <NA>
#
#                                                                                   \
#                                                          LocatedContractingParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                               ParentLocatedParty
#                                                                        PartyName
#                                                                             Name
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                      <NA>
#                                                    452                      <NA>
#
#                                                                              \
#
#
#
#
#                                                          ParentLocatedParty
#                                                                   PartyName
#                                                                        Name
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                 <NA>
#                                                    452                 <NA>
#
#                                                                                               \
#                                                                             TenderingProcess
#                                                          ParticipationRequestReceptionPeriod
#                                                                                      EndDate
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453                            2017-11-02
#                                                    452                            2017-11-02
#
#                                                                     \
#
#
#                                                            EndTime
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453    23:59:00
#                                                    452    23:59:00
#
#                                                                                          \
#
#                                                          TenderSubmissionDeadlinePeriod
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453        2017-11-02 23:59:00+00:00
#                                                    452        2017-11-02 23:59:00+00:00
#
#                                                          deleted_on
#
#
#
#
#
#
#
# file name                                          entry
# PlataformasAgregadasSinMenores_20180217_180137_... 453          NaT
#                                                    452          NaT

# %%
parquet_df.to_parquet(output_file.with_suffix('.parquet'))

# %% [markdown]
# ## Making a sample

# %% [markdown]
# If we are working with sample files, a *parquet* sample file is created

# %%
if outsiders_directory.parts[-2] == 'samples':
    sample_df  = parquet_df.iloc[itertools.chain(range(10), range(-10, 0))]
    sample_df.to_parquet(outsiders_directory.parent / '2018-2021_20samples.parquet')
